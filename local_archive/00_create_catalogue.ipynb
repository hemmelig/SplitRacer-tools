# %% [markdown]
# # Create catalogue of teleseismic events suitable for XKS splitting
#
# SplitRacer provides utilities for creating a catalogue of suitable events via an interface to the FDSN request servers. In order to use SplitRacer with data from a locally stored data archive, one needs to create this event catalogue.
#
# The general idea is to loop over each station and create an ObsPy catalogue of events between epicentral distances of 85 to 180 degrees. These catalogues are stored individually, so as to ensure waveform data is only cut for suitable event-station pairs.

# %%
# --- Imports ---
import pathlib

import numpy as np
import obspy
from obspy.clients.fdsn import Client
import pandas as pd

# %% [markdown]
# ## Setup client and read in station information
#
# Station information needs to be parsed into a pandas DataFrame. This can either be from a .csv file or using the provided utility function to parse the required information from a response inventory.

# %%
# --- Setup ---
# Initialise a client object
client = Client("IRIS")

# Specify the time period over which to query the online catalogue
starttime = obspy.UTCDateTime("2009-07-28")
endtime = obspy.UTCDateTime("2012-200")

# %%
# --- Station information ---
stations = pd.read_csv("/path/to/station_file")

# %%
# --- Station inventory ---
inventory = obspy.read_inventory("/path/to/inventory_file")

# %% [markdown]
# ## Setup parameters
#
# Here we specify the parameters used to filter/select the events for the catalogue. Typically, core phases appear at epicentral distances beyond ~85 degrees, though each phase (e.g. SKS, SKKS, PKS, PKKS, SKIKS, PKIKS) is most suitable in different ranges of angle bands.
#
# The best earthquakes for this type of analysis are those that are intermediate- or deep-focus and have magnitude in excess of ~ 5.8.

# %%
min_magnitude = 5.8
min_epicentral_distance = 85
max_epicentral_distance = 180

output_path = pathlib.Path.cwd() / "catalogues"
output_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Generate catalogues for each station
#
# Generate individual event catalogues for each station. If you wish to run the analysis under one directory, you should merge the resultant catalogues. Otherwise, keeping each catalogue distinct should minimise the amount of attempted pre-processing.
#
# You may find the process can time out. A list of processed stations is constructed so the process can be restarted without having to re-download event catalogues that already exist.
#
# If a catalogue of events for a station fails, I advise you to just take the event catalogue for the nearest station, or try to run the `get_events` command again for that specific station.
#
# ### From `pandas.DataFrame` of stations

# %%
catalogues, stations_processed = [], []

# %%
for _, station in stations.iterrows():
    if station.Name in stations_processed:
        continue
    print(f"Working on {station.Name}...")
    try:
        catalogue = client.get_events(
            starttime=starttime,
            endtime=endtime,
            minmagnitude=min_magnitude, 
            latitude=station.Latitude,
            longitude=station.Longitude,
            minradius=min_epicentral_distance,
            maxradius=max_epicentral_distance)
    except:
        print("    ...catalogue creation failed. Continuing.")
    print(f"    ...catalogue contains {len(catalogue)} events.")
    catalogues.append(catalogue)

    fname = (f"{starttime.year}_{starttime.julday:03d}-"
             f"{endtime.year}_{endtime.julday:03d}_"
             f"{min_epicentral_distance}-{max_epicentral_distance}_"
             f"{station.Name}_m{min_magnitude}_XKS_Catalogue.xml")
    catalogue.write(str(output_path / fname), format="QUAKEML")
    stations_processed.append(station.Name)
# Out:
# Working on K006...
#     ...catalogue contains 574 events.
# Working on K008...
#     ...catalogue contains 573 events.
# Working on K009...
#     ...catalogue contains 572 events.
# Working on K010...
#     ...catalogue contains 574 events.
# Working on K020...
#     ...catalogue contains 574 events.
# Working on K025...
#     ...catalogue contains 574 events.
# Working on K030...
#     ...catalogue contains 573 events.
# Working on K040...
#     ...catalogue contains 573 events.
# Working on K050...
#     ...catalogue contains 573 events.
# Working on K055...
#     ...catalogue contains 574 events.
# Working on K060...
#     ...catalogue contains 574 events.
# Working on K070...
#     ...catalogue contains 573 events.
# Working on K071...
#     ...catalogue contains 573 events.
# Working on K080...
#     ...catalogue contains 573 events.
# Working on K085...
#     ...catalogue contains 574 events.
# Working on K090...
#     ...catalogue contains 574 events.
# Working on K100...
#     ...catalogue contains 573 events.
# Working on K110...
#     ...catalogue contains 573 events.
# Working on K115...
#     ...catalogue contains 574 events.
# Working on K120...
#     ...catalogue contains 574 events.
# Working on K130...
#     ...catalogue contains 573 events.
# Working on K140...
#     ...catalogue contains 573 events.
# Working on K160...
#     ...catalogue contains 573 events.
# Working on K170...
#     ...catalogue contains 573 events.
# Working on K180...
#     ...catalogue contains 572 events.
# Working on K190...
#     ...catalogue contains 574 events.
# Working on K200...
#     ...catalogue contains 573 events.
# Working on K210...
#     ...catalogue contains 573 events.
# Working on K219...
#     ...catalogue contains 574 events.
# Working on K220...
#     ...catalogue contains 574 events.
# Working on K230...
#     ...catalogue contains 574 events.
# Working on K240...
#     ...catalogue contains 574 events.
# Working on K250...
#     ...catalogue contains 574 events.
# Working on VIKI...
#     ...catalogue contains 569 events.
# Working on VVAT...
#     ...catalogue contains 569 events.
# Working on N66D...
#     ...catalogue contains 569 events.
# Working on GUDF...
#     ...catalogue contains 572 events.
# Working on BUNG...
#     ...catalogue contains 570 events.
# Working on KVIH...
#     ...catalogue contains 574 events.
# Working on DRUM...
#     ...catalogue contains 574 events.
# Working on HVAN...
#     ...catalogue contains 574 events.
# Working on BURF...
#     ...catalogue contains 574 events.
# Working on SKOG...
#     ...catalogue contains 573 events.
# Working on TREB...
#     ...catalogue contains 574 events.
# Working on BLAF...
#     ...catalogue contains 574 events.
# Working on SBLA...
#     ...catalogue contains 574 events.
# Working on KODA...
#     ...catalogue contains 574 events.

# %% [markdown]
# ### From `obspy.Inventory` object

# %%
catalogues, stations_processed = [], []

# %%
for network in inventory:
    for station in network:
        if station.Name in stations_processed:
            continue
        print(f"Working on {station.Name}...")
        catalogue = client.get_events(
            starttime=starttime,
            endtime=endtime,
            minmagnitude=min_magnitude, 
            latitude=station.Latitude,
            longitude=station.Longitude,
            minradius=min_epicentral_distance,
            maxradius=max_epicentral_distance)
        print(f"    ...catalogue contains {len(catalogue)} events.")
        catalogues.append(catalogue)

        catalogue.write(str(output_path / (f"{min_epicentral_distance}-"
                                           f"{max_epicentral_distance}_"
                                           f"{station.Name}_m{min_magnitude}"
                                           "_XKS_Catalogue.xml")),
                        format="QUAKEML")
        stations_processed.append(station.Name)

# %% [markdown]
# ## Write the events to file
#
# ### Combine into single catalogue before writing

# %%
final_catalogue = obspy.Catalog()
event_ids = []
for catalogue in catalogues:
    for event in catalogue:
        if event.resource_id not in event_ids:
            print(f"Adding new event - {event.resource_id}")
            event_ids.append(event.resource_id)
            final_catalogue += event
# Out:
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8761009
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3343450
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3343342
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8755727
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8751710
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3342649
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8742073
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8736016
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3341014
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8723960
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3340943
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8720345
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8720170
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8717457
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8716017
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8711688
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8711429
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3340371
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3340348
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8705195
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3340155
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8699329
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3339808
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8695487
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3339476
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8688267
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8678737
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338676
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338556
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338312
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338251
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338106
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338104
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338105
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338102
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338100
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338099
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337914
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337867
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337862
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337810
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337774
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337766
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337757
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337735
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337559
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337556
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337502
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337499
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3338583
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3340172
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337497
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337318
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3337087
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3336760
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3336558
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3336491
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3336451
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3336353
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3336219
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3336133
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3335822
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3335575
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3335559
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3335514
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3335116
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3335114
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3334540
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3334422
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3334228
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3334218
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=4827592
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3334064
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3334061
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3334049
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3334015
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333999
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333932
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333921
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333690
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333645
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333415
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333410
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333348
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333304
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333193
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333173
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333034
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=4786647
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3333033
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3332981
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3332757
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3332690
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3332010
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3331925
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3331879
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3331877
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3331408
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3331341
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3331339
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3331279
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3331204
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3331044
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3330998
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3330598
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3330560
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3330518
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3330284
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3330045
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3329884
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3329830
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3329704
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3329513
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3325000
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3324991
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3324879
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3324716
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3324631
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3324521
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3324246
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3323982
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3323791
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3323712
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3323426
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3323397
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3323312
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3323308
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3322607
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3322556
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3322252
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3322189
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3322145
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3322079
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3322026
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321933
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321589
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321563
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321553
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321530
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321580
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321502
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321499
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321489
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321332
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3321216
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3320971
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3320964
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3320854
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3320794
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3320765
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3320760
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3320758
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3320665
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3320440
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3319565
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3319178
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3319171
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3318957
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3318736
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3318656
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3318598
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3318415
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3318355
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3318311
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3318050
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3317990
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3317982
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3317674
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3317618
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3317556
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3317551
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3317547
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3317449
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3317325
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3317258
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3316802
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3316557
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3316476
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3316329
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3316325
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3315088
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3314962
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3314914
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3289310
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3289182
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3289136
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3288885
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8673808
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8661730
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3288133
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3287730
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3286937
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3286933
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3286576
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3285885
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3285781
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3285163
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3285033
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3284483
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3284455
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3284191
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3282441
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3282416
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3282260
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3282255
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3282159
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3281051
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3280834
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3280556
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3280411
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3280113
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3280101
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3279518
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3279356
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3279347
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3279188
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=9853256
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3279149
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3279146
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3278515
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3278499
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3278481
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3278416
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3278381
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3278044
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277987
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277929
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277928
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277925
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277878
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277873
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277872
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277870
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277780
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277775
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277679
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277467
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277454
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3277104
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3276654
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3276652
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3276486
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3275975
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3275966
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3275945
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3275943
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3275814
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3275813
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3275804
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3275250
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3275249
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3275248
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207702
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207533
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207532
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207531
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207526
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207524
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207318
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207441
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=8207976
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207124
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207073
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3207018
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3206757
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3206680
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3206420
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3206419
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3206359
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3206286
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3203700
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3202780
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3202771
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3181487
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3203573
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3181484
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3181174
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3181172
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3181170
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3181114
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180846
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180679
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180678
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180677
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3156956
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2873489
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=369332
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=1
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180596
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180594
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180566
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180560
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180532
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180450
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180448
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180384
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3180383
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2880326
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2880282
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2880266
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2880239
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2880163
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2880142
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2880141
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2880069
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2879839
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2879764
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2879713
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2879699
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2879659
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2879627
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2879598
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2879424
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=4126719
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2879335
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2879322
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878749
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878719
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878589
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878496
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878474
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878440
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=4108776
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878374
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878283
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878236
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878080
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2878067
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2877974
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2877701
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2877668
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2877593
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2877587
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2877550
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2877199
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876807
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876716
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876688
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876684
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876683
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876682
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876678
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876495
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876363
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876250
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2876239
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2875597
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2875581
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2875275
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2875256
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2875161
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2875090
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2875009
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874958
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874756
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874733
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874669
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874617
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874510
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874503
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874412
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874365
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874224
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874163
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874057
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874051
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2874049
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2873844
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2873720
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2851219
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2851207
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2851152
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2851140
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850991
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850974
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850951
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850899
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850806
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850645
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850614
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=4027758
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850458
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850173
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850116
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850037
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2850011
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2849987
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2849975
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2849912
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2849845
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2849705
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2849490
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2849415
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2849388
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2849314
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2849132
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2848720
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2848694
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2848667
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2848630
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2848604
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2848377
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2848283
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2848131
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2848016
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2847737
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2847609
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2847548
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2847446
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2847389
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2847283
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2847149
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846870
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846867
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3968128
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846734
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846702
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846691
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846670
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846509
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846507
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846505
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846308
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846275
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846227
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846205
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846087
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846077
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846070
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846042
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2846012
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845969
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845965
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845949
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845940
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845774
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845581
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845490
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845345
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845322
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845319
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845258
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845237
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845207
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845083
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845081
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3952728
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845072
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845033
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845026
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2845013
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844998
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844996
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844990
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844989
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844986
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844782
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844683
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844620
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844558
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844449
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844424
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844395
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844292
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844256
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844224
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844147
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2844021
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2843905
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2843858
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2843838
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2843768
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2843369
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2843264
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2843222
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2843189
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842955
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842826
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842817
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842806
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842768
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842720
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842711
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842691
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842671
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842602
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842430
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842313
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842220
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2842054
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2841908
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2841896
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2841675
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2841506
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2841497
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2841485
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2841349
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2841295
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2841294
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2841270
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840991
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840937
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840930
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840846
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840820
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840778
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840676
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840563
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840546
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840512
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840331
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840269
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840246
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840201
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840193
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2840056
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839915
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839867
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839857
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839790
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839713
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839621
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839613
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839546
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839531
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839510
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839424
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839381
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839376
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839375
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839346
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839344
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839319
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839308
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839302
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3834372
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839297
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839294
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839291
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839155
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839121
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2839043
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838991
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838922
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838906
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838892
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838868
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838813
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=3826349
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838722
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838721
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838528
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838365
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838349
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838335
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2838018
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2837947
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2837862
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2837840
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2837741
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2837616
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2873170
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2873074
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2873052
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2873020
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2872995
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2872827
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2872699
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2872673
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2872508
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2872494
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2872399
# Adding new event - smi:service.iris.edu/fdsnws/event/1/query?eventid=2872371

# %% [markdown]
# ### Create event list file

# %%
# --- Functions ---
def write_eventlist(fname, catalogue):
    """
    Short utility function to export an ObsPy Catalog to the SplitRacer event
    list file format.

    Parameters
    ----------
    fname : str
        Name of event list file.
    catalogue : `obspy.Catalog` object
        A catalogue of `obspy.Event` objects, which contain event information.

    """

    with open(fname, "w") as f:
        for event in catalogue:
            origin = event.origins[0]
            magnitude = event.magnitudes[0]
            out = fmt.format(str(origin.time),
                             origin.latitude,
                             origin.longitude,
                             origin.depth/1000,
                             magnitude.mag,
                             magnitude.magnitude_type)
            print(out, file=f)
            
line = "time |  latitude |      longitude |     depth | mag |   magType"
fmt = "{} {:3.3f} {:3.3f} {} {:3.1f} {}"

# %%
# For the entire catalogue
write_eventlist("eventlist_all.txt", final_catalogue)

# %%
# Or each station catalogue separately
for station, catalogue in zip(stations_processed, catalogues):
    write_eventlist(f"eventlist_{station}.txt", catalogue)
